# %%
# Import required libraries
import os

class Satellite:
    def __init__(self, name, tle1, tle2):
        """Initializes a GPS satellite object with TLE data.
        :param name: Name of the satellite
        :param tle1: First line of TLE
        :param tle2: Second line of TLE"""
        self.name = name.strip()
        self.tle1 = tle1.strip()
        self.tle2 = tle2.strip()
        self.ssc_number = self.tle1.split()[1]  # Extract SSC Number
        self.epoch = self.tle1.split()[3]  # Extract reference epoch
        self.mean_anomaly = self.tle2.split()[6]  # Extract Mean Anomaly
        self.inclination = self.tle2.split()[2]  # Extract Inclination
        self.raan = self.tle2.split()[3]  # Extract Right Ascension of Ascending Node (RAAN)

    def __str__(self):
        """String representation of the Satellite object, formatted like your expected output."""
        return (f"\nSatellite name: {self.name}\n"
                f"SSC Number: {self.ssc_number}\n"
                f"Reference Epoch: {self.epoch}\n"
                f"Mean anomaly: {self.mean_anomaly}\n"
                f"Inclination: {self.inclination}°\n"
                f"RAAN: {self.raan}°\n"
                f"TLE data:\n{self.tle1}\n{self.tle2}\n")


def load_gps_tle(tle_file):
    """Reads the GPS TLE file and returns a list of Satellite objects.
    :param tle_file: Path to the TLE file
    :return: List of Satellite objects"""
    if not os.path.exists(tle_file):
        raise FileNotFoundError(f"Error: TLE file '{tle_file}' not found.")

    satellites = []
    with open(tle_file, 'r') as file:
        lines = file.readlines()

    i = 0
    while i < len(lines) - 2:
        name = lines[i].strip()
        tle1 = lines[i + 1].strip()
        tle2 = lines[i + 2].strip()
        satellites.append(Satellite(name, tle1, tle2))
        i += 3  # Move to next satellite

    return satellites

# %%
# Provide the correct file path
tle_path=r'C:\Users\hish13\\Desktop\Hardware_Tracking_Software-MAIN 3\Hardware_Tracking_Software-main\gps-ops.txt'

SatCons = load_gps_tle(tle_path)

for sat in SatCons:
    if 'PRN 19' in sat.name or 'PRN 19' in sat.tle1:
        print("Found PRN 19:")
        print(sat)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Provide the correct file path
#       2 tle_path=r'C:\Users\hish13\\Desktop\Hardware_Tracking_Software-MAIN 3\Hardware_Tracking_Software-main\gps-ops.txt'
# ----> 4 SatCons = load_gps_tle(tle_path)
#       6 for sat in SatCons:
#       7     if 'PRN 19' in sat.name or 'PRN 19' in sat.tle1:
#
# Cell In[2], line 35, in load_gps_tle(tle_file)
#      31 """Reads the GPS TLE file and returns a list of Satellite objects.
#      32 :param tle_file: Path to the TLE file
#      33 :return: List of Satellite objects"""
#      34 if not os.path.exists(tle_file):
# ---> 35     raise FileNotFoundError(f"Error: TLE file '{tle_file}' not found.")
#      37 satellites = []
#      38 with open(tle_file, 'r') as file:
#
# FileNotFoundError: Error: TLE file 'C:\Users\hish13\\Desktop\Hardware_Tracking_Software-MAIN 3\Hardware_Tracking_Software-main\gps-ops.txt' not found.

# %%
for i, sat in enumerate(gps_satellites, start=1):
    print(f"{'-'*80}")
    print(f"Satellite {i}")
    print(str(sat))
# Out:
# --------------------------------------------------------------------------------
# Satellite 1
#
# Satellite name: GPS BIIR-2  (PRN 13)
# SSC Number: 24876U
# Reference Epoch: 25076.50113892
# Mean anomaly: 307.0179
# Inclination: 55.7681°
# RAAN: 116.4396°
# TLE data:
# 1 24876U 97035A   25076.50113892  .00000022  00000+0  00000+0 0  9992
# 2 24876  55.7681 116.4396 0087517  53.8663 307.0179  2.00562662202796
#
# --------------------------------------------------------------------------------
# Satellite 2
#
# Satellite name: GPS BIIR-4  (PRN 20)
# SSC Number: 26360U
# Reference Epoch: 25076.54733222
# Mean anomaly: 252.1546
# Inclination: 54.8755°
# RAAN: 37.7683°
# TLE data:
# 1 26360U 00025A   25076.54733222 -.00000071  00000+0  00000+0 0  9999
# 2 26360  54.8755  37.7683 0038073 231.5337 252.1546  2.00557665182116
#
# --------------------------------------------------------------------------------
# Satellite 3
#
# Satellite name: GPS BIIR-5  (PRN 22)
# SSC Number: 26407U
# Reference Epoch: 25076.84032215
# Mean anomaly: 234.6900
# Inclination: 54.9693°
# RAAN: 233.2948°
# TLE data:
# 1 26407U 00040A   25076.84032215  .00000028  00000+0  00000+0 0  9996
# 2 26407  54.9693 233.2948 0134307 298.5380 234.6900  2.00564469180796
#
# --------------------------------------------------------------------------------
# Satellite 4
#
# Satellite name: GPS BIIR-8  (PRN 16)
# SSC Number: 27663U
# Reference Epoch: 25076.42051829
# Mean anomaly: 320.8020
# Inclination: 55.0049°
# RAAN: 233.1219°
# TLE data:
# 1 27663U 03005A   25076.42051829  .00000024  00000+0  00000+0 0  9997
# 2 27663  55.0049 233.1219 0143488  49.8587 320.8020  2.00559402162156
#
# --------------------------------------------------------------------------------
# Satellite 5
#
# Satellite name: GPS BIIR-11 (PRN 19)
# SSC Number: 28190U
# Reference Epoch: 25076.63361419
# Mean anomaly: 162.3344
# Inclination: 55.2165°
# RAAN: 294.0865°
# TLE data:
# 1 28190U 04009A   25076.63361419 -.00000026  00000+0  00000+0 0  9993
# 2 28190  55.2165 294.0865 0101788 157.3926 162.3344  2.00570212153818
#
# --------------------------------------------------------------------------------
# Satellite 6
#
# Satellite name: GPS BIIR-13 (PRN 02)
# SSC Number: 28474U
# Reference Epoch: 25076.60794208
# Mean anomaly: 56.7114
# Inclination: 55.3549°
# RAAN: 343.2547°
# TLE data:
# 1 28474U 04045A   25076.60794208 -.00000094  00000+0  00000+0 0  9996
# 2 28474  55.3549 343.2547 0163994 301.2774  56.7114  2.00657839149268
#
# --------------------------------------------------------------------------------
# Satellite 7
#
# Satellite name: GPS BIIRM-1 (PRN 17)
# SSC Number: 28874U
# Reference Epoch: 25076.38889758
# Mean anomaly: 239.6850
# Inclination: 55.2615°
# RAAN: 291.5665°
# TLE data:
# 1 28874U 05038A   25076.38889758 -.00000024  00000+0  00000+0 0  9996
# 2 28874  55.2615 291.5665 0133399 289.5874 239.6850  2.00566897142676
#
# --------------------------------------------------------------------------------
# Satellite 8
#
# Satellite name: GPS BIIRM-2 (PRN 31)
# SSC Number: 29486U
# Reference Epoch: 25076.36278344
# Mean anomaly: 5.2487
# Inclination: 54.6795°
# RAAN: 169.4624°
# TLE data:
# 1 29486U 06042A   25076.36278344  .00000017  00000+0  00000+0 0  9994
# 2 29486  54.6795 169.4624 0104401  45.3925   5.2487  2.00567907135233
#
# --------------------------------------------------------------------------------
# Satellite 9
#
# Satellite name: GPS BIIRM-3 (PRN 12)
# SSC Number: 29601U
# Reference Epoch: 25076.22069781
# Mean anomaly: 275.7895
# Inclination: 55.0440°
# RAAN: 232.1281°
# TLE data:
# 1 29601U 06052A   25076.22069781  .00000022  00000+0  00000+0 0  9998
# 2 29601  55.0440 232.1281 0087611  85.1677 275.7895  2.00557569134240
#
# --------------------------------------------------------------------------------
# Satellite 10
#
# Satellite name: GPS BIIRM-4 (PRN 15)
# SSC Number: 32260U
# Reference Epoch: 25076.03144397
# Mean anomaly: 281.8500
# Inclination: 53.7682°
# RAAN: 98.9470°
# TLE data:
# 1 32260U 07047A   25076.03144397  .00000010  00000+0  00000+0 0  9991
# 2 32260  53.7682  98.9470 0159065  80.0009 281.8500  2.00551453127645
#
# --------------------------------------------------------------------------------
# Satellite 11
#
# Satellite name: GPS BIIRM-5 (PRN 29)
# SSC Number: 32384U
# Reference Epoch: 25076.09269698
# Mean anomaly: 20.3366
# Inclination: 55.4054°
# RAAN: 292.4813°
# TLE data:
# 1 32384U 07062A   25076.09269698 -.00000026  00000+0  00000+0 0  9991
# 2 32384  55.4054 292.4813 0029678 153.4361  20.3366  2.00562507126342
#
# --------------------------------------------------------------------------------
# Satellite 12
#
# Satellite name: GPS BIIRM-6 (PRN 07)
# SSC Number: 32711U
# Reference Epoch: 25076.44057415
# Mean anomaly: 116.1301
# Inclination: 54.4567°
# RAAN: 168.1569°
# TLE data:
# 1 32711U 08012A   25076.44057415  .00000017  00000+0  00000+0 0  9991
# 2 32711  54.4567 168.1569 0195480 241.9210 116.1301  2.00555835124596
#
# --------------------------------------------------------------------------------
# Satellite 13
#
# Satellite name: GPS BIIRM-8 (PRN 05)
# SSC Number: 35752U
# Reference Epoch: 25076.66604890
# Mean anomaly: 98.9849
# Inclination: 55.8972°
# RAAN: 45.4376°
# TLE data:
# 1 35752U 09043A   25076.66604890 -.00000057  00000+0  00000+0 0  9998
# 2 35752  55.8972  45.4376 0053993  74.9031  98.9849  2.00553128114203
#
# --------------------------------------------------------------------------------
# Satellite 14
#
# Satellite name: GPS BIIF-1  (PRN 25)
# SSC Number: 36585U
# Reference Epoch: 25074.01690919
# Mean anomaly: 117.5715
# Inclination: 54.3654°
# RAAN: 227.0668°
# TLE data:
# 1 36585U 10022A   25074.01690919 -.00000005  00000+0  00000+0 0  9999
# 2 36585  54.3654 227.0668 0121659  63.7359 117.5715  2.00565198108387
#
# --------------------------------------------------------------------------------
# Satellite 15
#
# Satellite name: GPS BIIF-3  (PRN 24)
# SSC Number: 38833U
# Reference Epoch: 25076.62292547
# Mean anomaly: 301.7396
# Inclination: 53.5272°
# RAAN: 162.2925°
# TLE data:
# 1 38833U 12053A   25076.62292547  .00000016  00000+0  00000+0 0  9998
# 2 38833  53.5272 162.2925 0163324  59.9208 301.7396  2.00561903 90284
#
# --------------------------------------------------------------------------------
# Satellite 16
#
# Satellite name: GPS BIIF-4  (PRN 27)
# SSC Number: 39166U
# Reference Epoch: 25075.98686150
# Mean anomaly: 314.2233
# Inclination: 54.8768°
# RAAN: 287.5553°
# TLE data:
# 1 39166U 13023A   25075.98686150 -.00000021  00000+0  00000+0 0  9998
# 2 39166  54.8768 287.5553 0132962  46.9128 314.2233  2.00561884 86717
#
# --------------------------------------------------------------------------------
# Satellite 17
#
# Satellite name: GPS BIIF-5  (PRN 30)
# SSC Number: 39533U
# Reference Epoch: 25076.48487537
# Mean anomaly: 136.2717
# Inclination: 53.6077°
# RAAN: 167.9382°
# TLE data:
# 1 39533U 14008A   25076.48487537  .00000016  00000+0  00000+0 0  9997
# 2 39533  53.6077 167.9382 0076713 223.1651 136.2717  2.00557997 80529
#
# --------------------------------------------------------------------------------
# Satellite 18
#
# Satellite name: GPS BIIF-6  (PRN 06)
# SSC Number: 39741U
# Reference Epoch: 25076.76987966
# Mean anomaly: 41.0392
# Inclination: 56.6694°
# RAAN: 349.2621°
# TLE data:
# 1 39741U 14026A   25076.76987966 -.00000096  00000+0  00000+0 0  9999
# 2 39741  56.6694 349.2621 0036616 318.7178  41.0392  2.00580760 79380
#
# --------------------------------------------------------------------------------
# Satellite 19
#
# Satellite name: GPS BIIF-7  (PRN 09)
# SSC Number: 40105U
# Reference Epoch: 25076.35204735
# Mean anomaly: 242.1314
# Inclination: 55.0658°
# RAAN: 106.6905°
# TLE data:
# 1 40105U 14045A   25076.35204735  .00000017  00000+0  00000+0 0  9999
# 2 40105  55.0658 106.6905 0028097 118.2192 242.1314  2.00554952 76910
#
# --------------------------------------------------------------------------------
# Satellite 20
#
# Satellite name: GPS BIIF-8  (PRN 03)
# SSC Number: 40294U
# Reference Epoch: 25076.22379363
# Mean anomaly: 296.9217
# Inclination: 56.6520°
# RAAN: 48.6147°
# TLE data:
# 1 40294U 14068A   25076.22379363 -.00000053  00000+0  00000+0 0  9990
# 2 40294  56.6520  48.6147 0056580  63.6440 296.9217  2.00577390 76048
#
# --------------------------------------------------------------------------------
# Satellite 21
#
# Satellite name: GPS BIIF-9  (PRN 26)
# SSC Number: 40534U
# Reference Epoch: 25076.36606225
# Mean anomaly: 325.9870
# Inclination: 53.2619°
# RAAN: 223.0789°
# TLE data:
# 1 40534U 15013A   25076.36606225  .00000020  00000+0  00000+0 0  9996
# 2 40534  53.2619 223.0789 0097667  34.6000 325.9870  2.00548884 72667
#
# --------------------------------------------------------------------------------
# Satellite 22
#
# Satellite name: GPS BIIF-10 (PRN 08)
# SSC Number: 40730U
# Reference Epoch: 25076.52633452
# Mean anomaly: 336.5476
# Inclination: 54.3570°
# RAAN: 285.8719°
# TLE data:
# 1 40730U 15033A   25076.52633452 -.00000016  00000+0  00000+0 0  9992
# 2 40730  54.3570 285.8719 0104556  23.9617 336.5476  2.00553010 70837
#
# --------------------------------------------------------------------------------
# Satellite 23
#
# Satellite name: GPS BIIF-11 (PRN 10)
# SSC Number: 41019U
# Reference Epoch: 25076.08356570
# Mean anomaly: 130.5013
# Inclination: 56.6295°
# RAAN: 48.4760°
# TLE data:
# 1 41019U 15062A   25076.08356570 -.00000053  00000+0  00000+0 0  9990
# 2 41019  56.6295  48.4760 0102998 228.5978 130.5013  2.00566824 68661
#
# --------------------------------------------------------------------------------
# Satellite 24
#
# Satellite name: GPS BIIF-12 (PRN 32)
# SSC Number: 41328U
# Reference Epoch: 25076.16943250
# Mean anomaly: 117.5631
# Inclination: 55.2517°
# RAAN: 107.6005°
# TLE data:
# 1 41328U 16007A   25076.16943250  .00000019  00000+0  00000+0 0  9990
# 2 41328  55.2517 107.6005 0087079 241.6228 117.5631  2.00574184 66715
#
# --------------------------------------------------------------------------------
# Satellite 25
#
# Satellite name: GPS BIII-1  (PRN 04)
# SSC Number: 43873U
# Reference Epoch: 25076.55449970
# Mean anomaly: 334.9818
# Inclination: 55.4176°
# RAAN: 110.2202°
# TLE data:
# 1 43873U 18109A   25076.55449970  .00000019  00000+0  00000+0 0  9995
# 2 43873  55.4176 110.2202 0033165 197.3245 334.9818  2.00566447 45911
#
# --------------------------------------------------------------------------------
# Satellite 26
#
# Satellite name: GPS BIII-2  (PRN 18)
# SSC Number: 44506U
# Reference Epoch: 25076.18991697
# Mean anomaly: 337.3469
# Inclination: 55.8054°
# RAAN: 349.2795°
# TLE data:
# 1 44506U 19056A   25076.18991697 -.00000098  00000+0  00000+0 0  9996
# 2 44506  55.8054 349.2795 0049134 193.8477 337.3469  2.00561089 40906
#
# --------------------------------------------------------------------------------
# Satellite 27
#
# Satellite name: GPS BIII-3  (PRN 23)
# SSC Number: 45854U
# Reference Epoch: 25076.27966116
# Mean anomaly: 338.4113
# Inclination: 56.3486°
# RAAN: 46.7263°
# TLE data:
# 1 45854U 20041A   25076.27966116 -.00000056  00000+0  00000+0 0  9991
# 2 45854  56.3486  46.7263 0051264 199.8371 338.4113  2.00568382 34873
#
# --------------------------------------------------------------------------------
# Satellite 28
#
# Satellite name: GPS BIII-4  (PRN 14)
# SSC Number: 46826U
# Reference Epoch: 25076.80743037
# Mean anomaly: 330.9914
# Inclination: 54.0885°
# RAAN: 229.2927°
# TLE data:
# 1 46826U 20078A   25076.80743037  .00000026  00000+0  00000+0 0  9991
# 2 46826  54.0885 229.2927 0055435 199.1783 330.9914  2.00558847 32352
#
# --------------------------------------------------------------------------------
# Satellite 29
#
# Satellite name: GPS BIII-5  (PRN 11)
# SSC Number: 48859U
# Reference Epoch: 25075.54640461
# Mean anomaly: 298.0016
# Inclination: 55.3358°
# RAAN: 350.8296°
# TLE data:
# 1 48859U 21054A   25075.54640461 -.00000102  00000+0  00000+0 0  9997
# 2 48859  55.3358 350.8296 0018626 230.4653 298.0016  2.00569722 27574
#
# --------------------------------------------------------------------------------
# Satellite 30
#
# Satellite name: GPS BIII-6  (PRN 28)
# SSC Number: 55268U
# Reference Epoch: 25055.80589204
# Mean anomaly: 308.9006
# Inclination: 55.0899°
# RAAN: 167.2640°
# TLE data:
# 1 55268U 23009A   25055.80589204  .00000001  00000+0  00000+0 0  9992
# 2 55268  55.0899 167.2640 0000971  39.5557 308.9006  2.00545614 15662
#
# --------------------------------------------------------------------------------
# Satellite 31
#
# Satellite name: GPS BIII-7  (PRN 01)
# SSC Number: 62339U
# Reference Epoch: 25074.28425002
# Mean anomaly: 131.4950
# Inclination: 54.9895°
# RAAN: 352.7626°
# TLE data:
# 1 62339U 24242A   25074.28425002 -.00000106  00000+0  00000+0 0  9994
# 2 62339  54.9895 352.7626 0004829 324.9796 131.4950  2.00557063  2057
